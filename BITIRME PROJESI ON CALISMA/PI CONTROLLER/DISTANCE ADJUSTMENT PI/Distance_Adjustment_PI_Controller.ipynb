# %%
# !pip install pyserial
# Out:
# Requirement already satisfied: pyserial in c:\users\90545\anaconda3\lib\site-packages (3.5)

# %%
import serial

print("Pyserial successfully imported!")
# Out:
# Pyserial successfully imported!

# %%
import random
import time

class SimulatedSensor:
    def __init__(self, initial_value=50, min_value=0, max_value=100):
        self.value = initial_value  # Başlangıç değeri
        self.min_value = min_value  # Minimum sınır
        self.max_value = max_value  # Maksimum sınır
        self.trend = 0  # Sensör değişim yönü (sabitlik veya dalgalanma için)

    def read(self):
        """Sensör verisini oku ve rastgele bir değişim uygula."""
        # Rastgele bir "gürültü" ekle
        noise = random.uniform(-5, 5)
        
        # Trend ile birleştir
        self.trend += random.uniform(-1, 1)  # Trend değişimi
        self.trend = max(-2, min(2, self.trend))  # Trend sınırlandırması
        
        # Yeni değer hesapla
        self.value += self.trend + noise
        
        # Değer sınırlandırma
        self.value = max(self.min_value, min(self.max_value, self.value))
        
        return self.value

# Sensör simülasyonu
sensor = SimulatedSensor()

# Sürekli veri üretme
try:
    while True:
        measured_value = sensor.read()  # Sensör verisi al
        print(f"Measured Distance: {measured_value:.2f}")
        time.sleep(0.1)  # 100 ms'lik bir okuma süresi (tipik bir sensör için)
except KeyboardInterrupt:
    print("Simulation stopped.")
# Out:
# Measured Distance: 47.72
# Measured Distance: 46.60
# Measured Distance: 48.15
# Measured Distance: 52.20
# Measured Distance: 55.35
# Measured Distance: 60.49
# Simulation stopped.

# %%
import random
import time

class SimulatedSensor:
    def __init__(self, initial_value=50, min_value=0, max_value=100):
        self.value = initial_value  # Başlangıç değeri
        self.min_value = min_value  # Minimum sınır
        self.max_value = max_value  # Maksimum sınır
        self.prev_value = initial_value  # Önceki mesafe
        self.prev_time = time.time()  # Başlangıç zamanı

    def read(self):
        """Sensör verisini oku ve rastgele bir değişim uygula."""
        # Rastgele bir "gürültü" ekle
        noise = random.uniform(-5, 5)
        
        # Mesafe değerini güncelle
        self.value += random.uniform(-1, 1) + noise
        self.value = max(self.min_value, min(self.max_value, self.value))  # Sınırlandır
        
        return self.value

    def get_speed(self):
        """Hızı mesafe farkı ve zaman farkı ile hesapla."""
        current_time = time.time()
        delta_time = current_time - self.prev_time  # Zaman farkı
        delta_distance = self.value - self.prev_value  # Mesafe farkı
        
        if delta_time > 0:  # Zaman farkı sıfır değilse
            speed = delta_distance / delta_time  # Hızı hesapla
        else:
            speed = 0  # Zaman farkı sıfırsa hız sıfır kabul edilir

        self.prev_value = self.value  # Önceki mesafeyi güncelle
        self.prev_time = current_time  # Önceki zamanı güncelle

        return speed

# PI Kontrolcüsü
class PIController:
    def __init__(self, target_speed, Kp, Ki):
        self.target_speed = target_speed  # Hedef hız (50 km/h)
        self.Kp = Kp  # Proportional (P) kazancı
        self.Ki = Ki  # Integral (I) kazancı
        self.prev_error = 0  # Önceki hata
        self.integral = 0  # Hata birikimi (integral)

    def control(self, current_speed):
        """PI kontrolünü uygula."""
        error = self.target_speed - current_speed  # Hata hesaplama
        self.integral += error  # Hata birikimi
        # Proportional ve Integral terimlerinin toplamı
        control_signal = self.Kp * error + self.Ki * self.integral
        return control_signal


# Sensör ve PI Kontrolcüsü nesneleri oluşturuluyor
sensor = SimulatedSensor(initial_value=50)  # Başlangıç değeri 50 cm
pi_controller = PIController(target_speed=50, Kp=0.1, Ki=0.05)  # Hedef hız 50 km/h

# Sürekli veri üretme ve PI kontrolü uygulama
try:
    while True:
        measured_distance = sensor.read()  # Sensör verisi al
        current_speed = sensor.get_speed()  # Hızı hesapla
        
        # Kontrolcü tarafından hız ayarı yapılır
        control_signal = pi_controller.control(current_speed)
        
        # Kontrol sinyali ile mesafeyi düzelt
        corrected_speed = current_speed + control_signal
        
        # Hedef hıza ulaşmak için düzeltmeler yapılır
        print(f"Measured Distance: {measured_distance:.2f} cm | Current Speed: {current_speed:.2f} cm/s | Corrected Speed: {corrected_speed:.2f} cm/s")
        
        time.sleep(0.1)  # 100 ms bekleme

except KeyboardInterrupt:
    print("Simulation stopped.")
# Out:
# Measured Distance: 48.62 cm | Current Speed: 0.00 cm/s | Corrected Speed: 7.50 cm/s
# Measured Distance: 46.36 cm | Current Speed: -22.44 cm/s | Corrected Speed: -9.07 cm/s
# Measured Distance: 47.32 cm | Current Speed: 9.48 cm/s | Corrected Speed: 21.68 cm/s
# Measured Distance: 44.20 cm | Current Speed: -31.02 cm/s | Corrected Speed: -10.72 cm/s
# Measured Distance: 41.88 cm | Current Speed: -23.06 cm/s | Corrected Speed: 0.10 cm/s
# Measured Distance: 44.34 cm | Current Speed: 24.44 cm/s | Corrected Speed: 44.12 cm/s
# Measured Distance: 40.40 cm | Current Speed: -39.10 cm/s | Corrected Speed: -8.60 cm/s
# Measured Distance: 38.36 cm | Current Speed: -20.39 cm/s | Corrected Speed: 11.75 cm/s
# Measured Distance: 38.43 cm | Current Speed: 0.69 cm/s | Corrected Speed: 33.19 cm/s
# Measured Distance: 37.29 cm | Current Speed: -11.34 cm/s | Corrected Speed: 25.44 cm/s
# Measured Distance: 39.95 cm | Current Speed: 26.47 cm/s | Corrected Speed: 60.64 cm/s
# Measured Distance: 38.54 cm | Current Speed: -14.02 cm/s | Corrected Speed: 27.39 cm/s
# Measured Distance: 39.25 cm | Current Speed: 6.97 cm/s | Corrected Speed: 48.44 cm/s
# Measured Distance: 40.12 cm | Current Speed: 8.75 cm/s | Corrected Speed: 52.11 cm/s
# Measured Distance: 40.73 cm | Current Speed: 5.98 cm/s | Corrected Speed: 51.81 cm/s
# Measured Distance: 39.33 cm | Current Speed: -13.94 cm/s | Corrected Speed: 37.08 cm/s
# Measured Distance: 42.02 cm | Current Speed: 26.85 cm/s | Corrected Speed: 74.95 cm/s
# Measured Distance: 46.01 cm | Current Speed: 39.58 cm/s | Corrected Speed: 86.92 cm/s
# Measured Distance: 44.23 cm | Current Speed: -17.68 cm/s | Corrected Speed: 38.78 cm/s
# Measured Distance: 40.48 cm | Current Speed: -37.49 cm/s | Corrected Speed: 25.32 cm/s
# Measured Distance: 37.40 cm | Current Speed: -30.57 cm/s | Corrected Speed: 35.58 cm/s
# Measured Distance: 40.09 cm | Current Speed: 26.69 cm/s | Corrected Speed: 88.28 cm/s
# Measured Distance: 42.05 cm | Current Speed: 19.47 cm/s | Corrected Speed: 83.31 cm/s
# Measured Distance: 37.20 cm | Current Speed: -48.13 cm/s | Corrected Speed: 27.37 cm/s
# Measured Distance: 40.85 cm | Current Speed: 36.19 cm/s | Corrected Speed: 103.95 cm/s
# Measured Distance: 40.60 cm | Current Speed: -2.49 cm/s | Corrected Speed: 71.77 cm/s
# Measured Distance: 43.79 cm | Current Speed: 31.68 cm/s | Corrected Speed: 103.43 cm/s
# Measured Distance: 40.34 cm | Current Speed: -34.10 cm/s | Corrected Speed: 48.44 cm/s
# Measured Distance: 39.76 cm | Current Speed: -5.74 cm/s | Corrected Speed: 76.75 cm/s
# Measured Distance: 38.04 cm | Current Speed: -17.12 cm/s | Corrected Speed: 69.86 cm/s
# Measured Distance: 33.38 cm | Current Speed: -46.46 cm/s | Corrected Speed: 48.28 cm/s
# Measured Distance: 32.18 cm | Current Speed: -11.90 cm/s | Corrected Speed: 82.48 cm/s
# Measured Distance: 28.51 cm | Current Speed: -36.27 cm/s | Corrected Speed: 64.86 cm/s
# Measured Distance: 24.61 cm | Current Speed: -38.88 cm/s | Corrected Speed: 66.95 cm/s
# Measured Distance: 24.95 cm | Current Speed: 3.32 cm/s | Corrected Speed: 107.27 cm/s
# Measured Distance: 27.24 cm | Current Speed: 22.91 cm/s | Corrected Speed: 126.25 cm/s
# Measured Distance: 29.34 cm | Current Speed: 20.22 cm/s | Corrected Speed: 125.32 cm/s
# Measured Distance: 27.24 cm | Current Speed: -20.76 cm/s | Corrected Speed: 91.97 cm/s
# Measured Distance: 23.81 cm | Current Speed: -34.10 cm/s | Corrected Speed: 84.17 cm/s
# Measured Distance: 24.02 cm | Current Speed: 2.14 cm/s | Corrected Speed: 119.18 cm/s
# Measured Distance: 19.69 cm | Current Speed: -43.12 cm/s | Corrected Speed: 83.11 cm/s
# Measured Distance: 22.06 cm | Current Speed: 23.64 cm/s | Corrected Speed: 144.51 cm/s
# Measured Distance: 21.29 cm | Current Speed: -7.72 cm/s | Corrected Speed: 119.17 cm/s
# Measured Distance: 24.66 cm | Current Speed: 33.57 cm/s | Corrected Speed: 157.15 cm/s
# Measured Distance: 19.41 cm | Current Speed: -52.02 cm/s | Corrected Speed: 85.22 cm/s
# Measured Distance: 16.47 cm | Current Speed: -29.26 cm/s | Corrected Speed: 109.67 cm/s
# Measured Distance: 15.53 cm | Current Speed: -9.32 cm/s | Corrected Speed: 130.58 cm/s
# Measured Distance: 18.11 cm | Current Speed: 25.67 cm/s | Corrected Speed: 163.29 cm/s
# Measured Distance: 19.57 cm | Current Speed: 14.55 cm/s | Corrected Speed: 155.06 cm/s
# Measured Distance: 21.72 cm | Current Speed: 21.42 cm/s | Corrected Speed: 162.67 cm/s
# Measured Distance: 18.52 cm | Current Speed: -31.94 cm/s | Corrected Speed: 118.74 cm/s
# Measured Distance: 16.59 cm | Current Speed: -19.22 cm/s | Corrected Speed: 133.65 cm/s
# Measured Distance: 14.47 cm | Current Speed: -21.10 cm/s | Corrected Speed: 135.51 cm/s
# Measured Distance: 16.26 cm | Current Speed: 17.84 cm/s | Corrected Speed: 172.17 cm/s
# Measured Distance: 11.97 cm | Current Speed: -42.88 cm/s | Corrected Speed: 122.16 cm/s
# Measured Distance: 15.05 cm | Current Speed: 30.78 cm/s | Corrected Speed: 189.41 cm/s
# Measured Distance: 13.99 cm | Current Speed: -10.62 cm/s | Corrected Speed: 155.18 cm/s
# Measured Distance: 19.30 cm | Current Speed: 52.90 cm/s | Corrected Speed: 212.21 cm/s
# Measured Distance: 15.49 cm | Current Speed: -37.99 cm/s | Corrected Speed: 134.81 cm/s
# Measured Distance: 18.63 cm | Current Speed: 31.25 cm/s | Corrected Speed: 198.06 cm/s
# Measured Distance: 21.28 cm | Current Speed: 26.38 cm/s | Corrected Speed: 194.86 cm/s
# Measured Distance: 25.63 cm | Current Speed: 43.48 cm/s | Corrected Speed: 210.58 cm/s
# Measured Distance: 28.40 cm | Current Speed: 27.42 cm/s | Corrected Speed: 197.25 cm/s
# Measured Distance: 30.60 cm | Current Speed: 22.01 cm/s | Corrected Speed: 193.78 cm/s
# Measured Distance: 32.34 cm | Current Speed: 17.30 cm/s | Corrected Speed: 191.18 cm/s
# Measured Distance: 36.18 cm | Current Speed: 38.15 cm/s | Corrected Speed: 210.53 cm/s
# Measured Distance: 39.53 cm | Current Speed: 33.40 cm/s | Corrected Speed: 207.09 cm/s
# Measured Distance: 39.98 cm | Current Speed: 4.43 cm/s | Corrected Speed: 183.30 cm/s
# Measured Distance: 43.37 cm | Current Speed: 33.79 cm/s | Corrected Speed: 210.53 cm/s
# Measured Distance: 41.35 cm | Current Speed: -20.10 cm/s | Corrected Speed: 165.53 cm/s
# Measured Distance: 36.24 cm | Current Speed: -50.85 cm/s | Corrected Speed: 142.90 cm/s
# Measured Distance: 34.78 cm | Current Speed: -14.56 cm/s | Corrected Speed: 178.79 cm/s
# Measured Distance: 31.13 cm | Current Speed: -36.38 cm/s | Corrected Speed: 163.47 cm/s
# Measured Distance: 35.52 cm | Current Speed: 43.85 cm/s | Corrected Speed: 235.99 cm/s
# Measured Distance: 37.37 cm | Current Speed: 18.39 cm/s | Corrected Speed: 214.66 cm/s
# Measured Distance: 32.39 cm | Current Speed: -49.42 cm/s | Corrected Speed: 158.59 cm/s
# Measured Distance: 32.42 cm | Current Speed: 0.24 cm/s | Corrected Speed: 205.78 cm/s
# Measured Distance: 33.23 cm | Current Speed: 8.15 cm/s | Corrected Speed: 214.99 cm/s
# Measured Distance: 33.29 cm | Current Speed: 0.58 cm/s | Corrected Speed: 210.64 cm/s
# Measured Distance: 34.13 cm | Current Speed: 8.31 cm/s | Corrected Speed: 219.68 cm/s
# Measured Distance: 34.81 cm | Current Speed: 6.78 cm/s | Corrected Speed: 220.47 cm/s
# Measured Distance: 38.20 cm | Current Speed: 33.77 cm/s | Corrected Speed: 245.57 cm/s
# Measured Distance: 41.01 cm | Current Speed: 27.91 cm/s | Corrected Speed: 241.41 cm/s
# Measured Distance: 39.83 cm | Current Speed: -11.72 cm/s | Corrected Speed: 208.82 cm/s
# Measured Distance: 38.37 cm | Current Speed: -14.58 cm/s | Corrected Speed: 209.47 cm/s
# Measured Distance: 40.02 cm | Current Speed: 16.48 cm/s | Corrected Speed: 239.10 cm/s
# Simulation stopped.

# %%
import random
import time

# Simüle edilmiş sensör
class SimulatedSensor:
    def __init__(self, initial_value=50, min_value=0, max_value=100):
        self.value = initial_value  # Başlangıç mesafesi
        self.min_value = min_value  # Minimum mesafe
        self.max_value = max_value  # Maksimum mesafe
        self.prev_value = initial_value  # Önceki mesafe
        self.prev_time = time.time()  # Başlangıç zamanı

    def read(self):
        """Sensör verisini oku ve rastgele bir değişim uygula."""
        noise = random.uniform(-5, 5)  # Gürültü
        self.value += random.uniform(-1, 1) + noise
        self.value = max(self.min_value, min(self.max_value, self.value))  # Sınırlandırma
        return self.value

    def get_speed(self):
        """Hızı, mesafe ve zaman farkına göre hesapla."""
        current_time = time.time()
        delta_time = current_time - self.prev_time  # Zaman farkı
        delta_distance = self.value - self.prev_value  # Mesafe farkı

        if delta_time > 0:
            speed = delta_distance / delta_time
        else:
            speed = 0

        self.prev_value = self.value
        self.prev_time = current_time
        return speed


# PI Kontrolcüsü
class PIController:
    def __init__(self, target_speed, Kp, Ki, Kd=0.05):
        self.target_speed = target_speed  # Hedef hız
        self.Kp = Kp  # Proportional kazancı
        self.Ki = Ki  # Integral kazancı
        self.Kd = Kd  # Derinlik kontrolü için mesafe kazancı
        self.integral = 0  # Hata birikimi

    def control(self, current_speed, measured_distance, target_distance=50):
        """Hem hız hem mesafeye dayalı PI kontrol."""
        # Hız hatası
        speed_error = self.target_speed - current_speed
        # Mesafe hatası
        distance_error = target_distance - measured_distance

        # Hata birikimi (integral terimi)
        self.integral += speed_error

        # Kontrol sinyali
        control_signal = (
            self.Kp * speed_error +
            self.Ki * self.integral +
            self.Kd * distance_error
        )
        return control_signal


# Simülasyon
sensor = SimulatedSensor(initial_value=50)  # Başlangıç mesafesi 50 cm
pi_controller = PIController(target_speed=0, Kp=0.1, Ki=0.05, Kd=0.02)  # Hedef hız 0 cm/s (durgunluk)

try:
    while True:
        # Sensör verisi al
        measured_distance = sensor.read()
        # Hızı hesapla
        current_speed = sensor.get_speed()

        # PI kontrolünü uygula
        control_signal = pi_controller.control(
            current_speed=current_speed,
            measured_distance=measured_distance,
            target_distance=50  # Hedef mesafe
        )

        # Kontrol sinyali ile hız düzeltilir
        corrected_speed = current_speed + control_signal

        # Durum bilgisi yazdır
        print(
            f"Measured Distance: {measured_distance:.2f} cm | "
            f"Current Speed: {current_speed:.2f} cm/s | "
            f"Corrected Speed: {corrected_speed:.2f} cm/s"
        )

        # Bekleme (100 ms)
        time.sleep(0.1)

except KeyboardInterrupt:
    print("Simulation stopped.")
# Out:
# Measured Distance: 49.42 cm | Current Speed: 0.00 cm/s | Corrected Speed: 0.01 cm/s
# Measured Distance: 47.35 cm | Current Speed: -20.50 cm/s | Corrected Speed: -17.37 cm/s
# Measured Distance: 45.94 cm | Current Speed: -14.03 cm/s | Corrected Speed: -10.82 cm/s
# Measured Distance: 48.04 cm | Current Speed: 20.91 cm/s | Corrected Speed: 19.54 cm/s
# Measured Distance: 45.46 cm | Current Speed: -25.65 cm/s | Corrected Speed: -21.03 cm/s
# Measured Distance: 47.85 cm | Current Speed: 23.87 cm/s | Corrected Speed: 22.29 cm/s
# Measured Distance: 51.72 cm | Current Speed: 38.47 cm/s | Corrected Speed: 33.43 cm/s
# Measured Distance: 53.28 cm | Current Speed: 15.48 cm/s | Corrected Speed: 11.94 cm/s
# Measured Distance: 50.20 cm | Current Speed: -30.70 cm/s | Corrected Speed: -28.03 cm/s
# Measured Distance: 50.89 cm | Current Speed: 6.86 cm/s | Corrected Speed: 5.42 cm/s
# Measured Distance: 53.08 cm | Current Speed: 21.89 cm/s | Corrected Speed: 17.81 cm/s
# Measured Distance: 49.04 cm | Current Speed: -40.33 cm/s | Corrected Speed: -36.09 cm/s
# Measured Distance: 51.57 cm | Current Speed: 25.22 cm/s | Corrected Speed: 21.59 cm/s
# Measured Distance: 56.15 cm | Current Speed: 45.46 cm/s | Corrected Speed: 37.44 cm/s
# Measured Distance: 51.75 cm | Current Speed: -43.80 cm/s | Corrected Speed: -40.61 cm/s
# Measured Distance: 49.62 cm | Current Speed: -21.23 cm/s | Corrected Speed: -19.19 cm/s
# Measured Distance: 53.25 cm | Current Speed: 36.11 cm/s | Corrected Speed: 30.53 cm/s
# Measured Distance: 56.79 cm | Current Speed: 35.24 cm/s | Corrected Speed: 27.92 cm/s
# Measured Distance: 55.00 cm | Current Speed: -17.87 cm/s | Corrected Speed: -18.96 cm/s
# Measured Distance: 55.52 cm | Current Speed: 5.26 cm/s | Corrected Speed: 1.59 cm/s
# Measured Distance: 58.42 cm | Current Speed: 28.74 cm/s | Corrected Speed: 21.22 cm/s
# Measured Distance: 53.76 cm | Current Speed: -46.36 cm/s | Corrected Speed: -43.95 cm/s
# Measured Distance: 53.45 cm | Current Speed: -3.03 cm/s | Corrected Speed: -4.79 cm/s
# Measured Distance: 49.21 cm | Current Speed: -42.13 cm/s | Corrected Speed: -37.80 cm/s
# Measured Distance: 48.02 cm | Current Speed: -11.92 cm/s | Corrected Speed: -9.99 cm/s
# Measured Distance: 52.12 cm | Current Speed: 40.70 cm/s | Corrected Speed: 35.25 cm/s
# Measured Distance: 50.63 cm | Current Speed: -14.77 cm/s | Corrected Speed: -13.91 cm/s
# Measured Distance: 44.88 cm | Current Speed: -57.08 cm/s | Corrected Speed: -49.01 cm/s
# Measured Distance: 40.65 cm | Current Speed: -41.96 cm/s | Corrected Speed: -33.22 cm/s
# Measured Distance: 42.45 cm | Current Speed: 17.88 cm/s | Corrected Speed: 19.70 cm/s
# Measured Distance: 44.04 cm | Current Speed: 15.87 cm/s | Corrected Speed: 17.07 cm/s
# Measured Distance: 46.39 cm | Current Speed: 23.40 cm/s | Corrected Speed: 22.63 cm/s
# Measured Distance: 42.81 cm | Current Speed: -35.69 cm/s | Corrected Speed: -28.69 cm/s
# Measured Distance: 41.55 cm | Current Speed: -12.54 cm/s | Corrected Speed: -7.20 cm/s
# Measured Distance: 43.98 cm | Current Speed: 24.12 cm/s | Corrected Speed: 24.54 cm/s
# Measured Distance: 47.28 cm | Current Speed: 32.91 cm/s | Corrected Speed: 30.74 cm/s
# Measured Distance: 48.40 cm | Current Speed: 11.19 cm/s | Corrected Speed: 10.60 cm/s
# Measured Distance: 52.23 cm | Current Speed: 38.06 cm/s | Corrected Speed: 32.80 cm/s
# Measured Distance: 52.93 cm | Current Speed: 7.02 cm/s | Corrected Speed: 4.50 cm/s
# Measured Distance: 50.92 cm | Current Speed: -20.05 cm/s | Corrected Speed: -18.81 cm/s
# Measured Distance: 47.48 cm | Current Speed: -34.17 cm/s | Corrected Speed: -29.75 cm/s
# Measured Distance: 50.73 cm | Current Speed: 32.37 cm/s | Corrected Speed: 28.46 cm/s
# Measured Distance: 50.09 cm | Current Speed: -6.30 cm/s | Corrected Speed: -6.02 cm/s
# Measured Distance: 45.01 cm | Current Speed: -50.28 cm/s | Corrected Speed: -42.99 cm/s
# Measured Distance: 42.42 cm | Current Speed: -25.70 cm/s | Corrected Speed: -19.53 cm/s
# Measured Distance: 40.86 cm | Current Speed: -15.58 cm/s | Corrected Speed: -9.61 cm/s
# Measured Distance: 42.82 cm | Current Speed: 19.52 cm/s | Corrected Speed: 20.96 cm/s
# Simulation stopped.

# %%
import random
import time

# Simüle edilmiş sensör
class SimulatedSensor:
    def __init__(self, initial_value=50, min_value=0, max_value=100):
        self.value = initial_value  # Başlangıç mesafesi
        self.min_value = min_value  # Minimum mesafe
        self.max_value = max_value  # Maksimum mesafe
        self.prev_value = initial_value  # Önceki mesafe
        self.prev_time = time.time()  # Başlangıç zamanı

    def read(self):
        """Sensör verisini oku ve rastgele bir değişim uygula."""
        noise = random.uniform(-5, 5)  # Gürültü
        self.value += random.uniform(-1, 1) + noise
        self.value = max(self.min_value, min(self.max_value, self.value))  # Sınırlandırma
        return self.value

    def get_speed(self):
        """Hızı, mesafe ve zaman farkına göre hesapla."""
        current_time = time.time()
        delta_time = current_time - self.prev_time  # Zaman farkı
        delta_distance = self.value - self.prev_value  # Mesafe farkı

        if delta_time > 0:
            speed = delta_distance / delta_time
        else:
            speed = 0

        self.prev_value = self.value
        self.prev_time = current_time
        return speed


# PI Kontrolcüsü
class PIController:
    def __init__(self, target_speed, Kp, Ki, Kd=0.05):
        self.target_speed = target_speed  # Hedef hız
        self.Kp = Kp  # Proportional kazancı
        self.Ki = Ki  # Integral kazancı
        self.Kd = Kd  # Mesafe kazancı
        self.integral = 0  # Hata birikimi

    def control(self, current_speed, measured_distance, target_distance=50):
        """Hem hız hem mesafeye dayalı PI kontrol."""
        # Hız hatası
        speed_error = self.target_speed - current_speed
        # Mesafe hatası
        distance_error = target_distance - measured_distance

        # Mantıksal kontrol: Mesafe hatasına göre hız yönünü düzelt
        if measured_distance > target_distance and current_speed > 0:
            # Mesafe fazla ve hız pozitifse, düzeltici hız negatif olmalı
            speed_error = -abs(speed_error)
        elif measured_distance < target_distance and current_speed < 0:
            # Mesafe az ve hız negatifse, düzeltici hız pozitif olmalı
            speed_error = abs(speed_error)

        # Hata birikimi (integral terimi)
        self.integral += speed_error

        # Kontrol sinyali
        control_signal = (
            self.Kp * speed_error +
            self.Ki * self.integral +
            self.Kd * distance_error
        )
        return control_signal


# Simülasyon
sensor = SimulatedSensor(initial_value=50)  # Başlangıç mesafesi 50 cm
pi_controller = PIController(target_speed=0, Kp=0.1, Ki=0.05, Kd=0.02)  # Hedef hız 0 cm/s (durgunluk)

try:
    while True:
        # Sensör verisi al
        measured_distance = sensor.read()
        # Hızı hesapla
        current_speed = sensor.get_speed()

        # PI kontrolünü uygula
        control_signal = pi_controller.control(
            current_speed=current_speed,
            measured_distance=measured_distance,
            target_distance=50  # Hedef mesafe
        )

        # Kontrol sinyali ile hız düzeltilir
        corrected_speed = current_speed + control_signal

        # Durum bilgisi yazdır
        print(
            f"Measured Distance: {measured_distance:.2f} cm | "
            f"Current Speed: {current_speed:.2f} cm/s | "
            f"Corrected Speed: {corrected_speed:.2f} cm/s"
        )

        # Bekleme (100 ms)
        time.sleep(0.1)

except KeyboardInterrupt:
    print("Simulation stopped.")
# Out:
# Measured Distance: 46.32 cm | Current Speed: 0.00 cm/s | Corrected Speed: 0.07 cm/s
# Measured Distance: 45.22 cm | Current Speed: -10.88 cm/s | Corrected Speed: -9.15 cm/s
# Measured Distance: 43.83 cm | Current Speed: -13.85 cm/s | Corrected Speed: -11.10 cm/s
# Measured Distance: 40.77 cm | Current Speed: -30.43 cm/s | Corrected Speed: -24.44 cm/s
# Measured Distance: 39.75 cm | Current Speed: -10.17 cm/s | Corrected Speed: -5.68 cm/s
# Measured Distance: 41.75 cm | Current Speed: 19.90 cm/s | Corrected Speed: 20.35 cm/s
# Measured Distance: 40.25 cm | Current Speed: -14.94 cm/s | Corrected Speed: -10.23 cm/s
# Measured Distance: 45.67 cm | Current Speed: 53.78 cm/s | Corrected Speed: 48.82 cm/s
# Measured Distance: 44.35 cm | Current Speed: -13.16 cm/s | Corrected Speed: -10.75 cm/s
# Measured Distance: 45.46 cm | Current Speed: 11.01 cm/s | Corrected Speed: 10.43 cm/s
# Measured Distance: 49.43 cm | Current Speed: 39.55 cm/s | Corrected Speed: 34.07 cm/s
# Measured Distance: 45.67 cm | Current Speed: -37.45 cm/s | Corrected Speed: -33.29 cm/s
# Measured Distance: 44.69 cm | Current Speed: -9.75 cm/s | Corrected Speed: -7.85 cm/s
# Measured Distance: 44.10 cm | Current Speed: -5.83 cm/s | Corrected Speed: -4.02 cm/s
# Measured Distance: 46.09 cm | Current Speed: 19.86 cm/s | Corrected Speed: 18.07 cm/s
# Measured Distance: 49.55 cm | Current Speed: 34.47 cm/s | Corrected Speed: 29.42 cm/s
# Measured Distance: 53.88 cm | Current Speed: 43.04 cm/s | Corrected Speed: 34.90 cm/s
# Measured Distance: 55.96 cm | Current Speed: 20.65 cm/s | Corrected Speed: 13.68 cm/s
# Measured Distance: 59.38 cm | Current Speed: 34.00 cm/s | Corrected Speed: 23.92 cm/s
# Measured Distance: 59.66 cm | Current Speed: 2.78 cm/s | Corrected Speed: -4.32 cm/s
# Measured Distance: 57.68 cm | Current Speed: -19.74 cm/s | Corrected Speed: -23.57 cm/s
# Measured Distance: 56.60 cm | Current Speed: -10.72 cm/s | Corrected Speed: -14.88 cm/s
# Measured Distance: 58.88 cm | Current Speed: 22.71 cm/s | Corrected Speed: 14.02 cm/s
# Measured Distance: 57.56 cm | Current Speed: -13.18 cm/s | Corrected Speed: -17.60 cm/s
# Measured Distance: 60.86 cm | Current Speed: 32.91 cm/s | Corrected Speed: 22.18 cm/s
# Measured Distance: 60.72 cm | Current Speed: -1.46 cm/s | Corrected Speed: -8.68 cm/s
# Measured Distance: 59.43 cm | Current Speed: -12.84 cm/s | Corrected Speed: -18.26 cm/s
# Measured Distance: 59.17 cm | Current Speed: -2.55 cm/s | Corrected Speed: -8.87 cm/s
# Measured Distance: 63.53 cm | Current Speed: 43.54 cm/s | Corrected Speed: 30.36 cm/s
# Measured Distance: 57.93 cm | Current Speed: -55.97 cm/s | Corrected Speed: -56.29 cm/s
# Measured Distance: 58.93 cm | Current Speed: 9.95 cm/s | Corrected Speed: 2.52 cm/s
# Measured Distance: 58.58 cm | Current Speed: -3.50 cm/s | Corrected Speed: -9.41 cm/s
# Measured Distance: 55.54 cm | Current Speed: -30.22 cm/s | Corrected Speed: -31.89 cm/s
# Measured Distance: 59.39 cm | Current Speed: 38.43 cm/s | Corrected Speed: 27.90 cm/s
# Measured Distance: 59.16 cm | Current Speed: -2.27 cm/s | Corrected Speed: -8.61 cm/s
# Measured Distance: 55.40 cm | Current Speed: -37.36 cm/s | Corrected Speed: -38.25 cm/s
# Measured Distance: 54.98 cm | Current Speed: -4.27 cm/s | Corrected Speed: -8.25 cm/s
# Measured Distance: 51.46 cm | Current Speed: -35.13 cm/s | Corrected Speed: -34.20 cm/s
# Measured Distance: 52.84 cm | Current Speed: 13.80 cm/s | Corrected Speed: 9.13 cm/s
# Measured Distance: 52.34 cm | Current Speed: -4.98 cm/s | Corrected Speed: -7.52 cm/s
# Measured Distance: 56.48 cm | Current Speed: 41.05 cm/s | Corrected Speed: 31.78 cm/s
# Measured Distance: 56.85 cm | Current Speed: 3.69 cm/s | Corrected Speed: -2.04 cm/s
# Measured Distance: 53.56 cm | Current Speed: -32.65 cm/s | Corrected Speed: -33.05 cm/s
# Measured Distance: 48.78 cm | Current Speed: -47.52 cm/s | Corrected Speed: -43.96 cm/s
# Measured Distance: 50.48 cm | Current Speed: 16.92 cm/s | Corrected Speed: 13.16 cm/s
# Measured Distance: 52.98 cm | Current Speed: 24.87 cm/s | Corrected Speed: 19.02 cm/s
# Measured Distance: 52.08 cm | Current Speed: -8.99 cm/s | Corrected Speed: -10.98 cm/s
# Measured Distance: 55.53 cm | Current Speed: 34.38 cm/s | Corrected Speed: 26.26 cm/s
# Measured Distance: 56.16 cm | Current Speed: 6.32 cm/s | Corrected Speed: 0.67 cm/s
# Measured Distance: 54.47 cm | Current Speed: -16.90 cm/s | Corrected Speed: -19.35 cm/s
# Measured Distance: 54.82 cm | Current Speed: 3.45 cm/s | Corrected Speed: -1.21 cm/s
# Measured Distance: 56.38 cm | Current Speed: 15.58 cm/s | Corrected Speed: 8.90 cm/s
# Measured Distance: 59.59 cm | Current Speed: 31.85 cm/s | Corrected Speed: 21.89 cm/s
# Measured Distance: 55.62 cm | Current Speed: -39.46 cm/s | Corrected Speed: -40.25 cm/s
# Measured Distance: 57.60 cm | Current Speed: 19.64 cm/s | Corrected Speed: 11.92 cm/s
# Simulation stopped.

# %%
import random
import time

# Simüle edilmiş sensör
class SimulatedSensor:
    def __init__(self, initial_value=50, min_value=0, max_value=100):
        self.value = initial_value  # Başlangıç mesafesi
        self.min_value = min_value  # Minimum mesafe
        self.max_value = max_value  # Maksimum mesafe
        self.prev_value = initial_value  # Önceki mesafe
        self.prev_time = time.time()  # Başlangıç zamanı

    def read(self):
        """Sensör verisini oku ve rastgele bir değişim uygula."""
        noise = random.uniform(-5, 5)  # Gürültü
        self.value += random.uniform(-1, 1) + noise
        self.value = max(self.min_value, min(self.max_value, self.value))  # Sınırlandırma
        return self.value

    def get_speed(self):
        """Hızı, mesafe ve zaman farkına göre hesapla."""
        current_time = time.time()
        delta_time = current_time - self.prev_time  # Zaman farkı
        delta_distance = self.value - self.prev_value  # Mesafe farkı

        if delta_time > 0:
            speed = delta_distance / delta_time
        else:
            speed = 0

        self.prev_value = self.value
        self.prev_time = current_time
        return speed


# PI Kontrolcüsü
class PIController:
    def __init__(self, target_speed, Kp, Ki, Kd=0.05):
        self.target_speed = target_speed  # Hedef hız
        self.Kp = Kp  # Proportional kazancı
        self.Ki = Ki  # Integral kazancı
        self.Kd = Kd  # Mesafe kazancı
        self.integral = 0  # Hata birikimi

    def control(self, current_speed, measured_distance, target_distance=50):
        """Hedef mesafeye ulaşmak için PI kontrol sinyali üret."""
        # Mesafe hatası
        distance_error = target_distance - measured_distance
        
        # Mesafeye göre hız yönlendirmesi
        if distance_error > 0:
            # Hedefe yaklaşmak için hız pozitif olmalı
            speed_error = abs(self.target_speed - current_speed)
        else:
            # Hedefe yaklaşmak için hız negatif olmalı
            speed_error = -abs(self.target_speed - current_speed)

        # Hata birikimi (integral terimi)
        self.integral += speed_error

        # Kontrol sinyali
        control_signal = (
            self.Kp * speed_error +  # Hız hatası katkısı
            self.Ki * self.integral +  # Hata birikimi katkısı
            self.Kd * distance_error   # Mesafe hatası katkısı
        )

        return control_signal


# Simülasyon
sensor = SimulatedSensor(initial_value=70)  # Başlangıç mesafesi 70 cm
pi_controller = PIController(target_speed=0, Kp=0.1, Ki=0.05, Kd=0.02)  # Hedef hız 0 cm/s (durgunluk)

try:
    while True:
        # Sensör verisi al
        measured_distance = sensor.read()
        # Hızı hesapla
        current_speed = sensor.get_speed()

        # PI kontrolünü uygula
        control_signal = pi_controller.control(
            current_speed=current_speed,
            measured_distance=measured_distance,
            target_distance=50  # Hedef mesafe
        )

        # Kontrol sinyali ile hız düzeltilir
        corrected_speed = current_speed + control_signal

        # Durum bilgisi yazdır
        print(
            f"Measured Distance: {measured_distance:.2f} cm | "
            f"Current Speed: {current_speed:.2f} cm/s | "
            f"Corrected Speed: {corrected_speed:.2f} cm/s",
            flush=True
        )

        # Bekleme (100 ms)
        time.sleep(0.1)

except KeyboardInterrupt:
    print("Simulation stopped.")
# Out:
# Measured Distance: 73.07 cm | Current Speed: 0.00 cm/s | Corrected Speed: -0.46 cm/s
# Measured Distance: 70.85 cm | Current Speed: -21.94 cm/s | Corrected Speed: -25.64 cm/s
# Measured Distance: 73.52 cm | Current Speed: 26.41 cm/s | Corrected Speed: 20.88 cm/s
# Measured Distance: 74.09 cm | Current Speed: 5.68 cm/s | Corrected Speed: 1.93 cm/s
# Measured Distance: 71.64 cm | Current Speed: -23.93 cm/s | Corrected Speed: -30.65 cm/s
# Measured Distance: 72.78 cm | Current Speed: 11.19 cm/s | Corrected Speed: 5.16 cm/s
# Measured Distance: 69.86 cm | Current Speed: -28.98 cm/s | Corrected Speed: -38.18 cm/s
# Measured Distance: 68.66 cm | Current Speed: -11.83 cm/s | Corrected Speed: -19.89 cm/s
# Measured Distance: 63.74 cm | Current Speed: -48.42 cm/s | Corrected Speed: -62.45 cm/s
# Measured Distance: 62.48 cm | Current Speed: -12.40 cm/s | Corrected Speed: -23.42 cm/s
# Measured Distance: 59.19 cm | Current Speed: -32.30 cm/s | Corrected Speed: -46.87 cm/s
# Measured Distance: 56.76 cm | Current Speed: -23.92 cm/s | Corrected Speed: -38.80 cm/s
# Measured Distance: 57.43 cm | Current Speed: 6.60 cm/s | Corrected Speed: -6.89 cm/s
# Measured Distance: 62.11 cm | Current Speed: 46.37 cm/s | Corrected Speed: 26.49 cm/s
# Measured Distance: 60.49 cm | Current Speed: -15.92 cm/s | Corrected Speed: -33.52 cm/s
# Measured Distance: 58.85 cm | Current Speed: -16.12 cm/s | Corrected Speed: -34.51 cm/s
# Measured Distance: 60.55 cm | Current Speed: 16.71 cm/s | Corrected Speed: -2.61 cm/s
# Measured Distance: 63.03 cm | Current Speed: 24.23 cm/s | Corrected Speed: 2.90 cm/s
# Measured Distance: 61.08 cm | Current Speed: -19.24 cm/s | Corrected Speed: -40.99 cm/s
# Measured Distance: 61.38 cm | Current Speed: 2.98 cm/s | Corrected Speed: -17.30 cm/s
# Measured Distance: 62.46 cm | Current Speed: 10.65 cm/s | Corrected Speed: -10.95 cm/s
# Measured Distance: 58.40 cm | Current Speed: -39.76 cm/s | Corrected Speed: -66.19 cm/s
# Measured Distance: 53.31 cm | Current Speed: -49.87 cm/s | Corrected Speed: -79.69 cm/s
# Measured Distance: 56.45 cm | Current Speed: 30.77 cm/s | Corrected Speed: 1.25 cm/s
# Measured Distance: 56.13 cm | Current Speed: -3.19 cm/s | Corrected Speed: -30.10 cm/s
# Measured Distance: 54.63 cm | Current Speed: -14.83 cm/s | Corrected Speed: -43.61 cm/s
# Measured Distance: 50.04 cm | Current Speed: -45.31 cm/s | Corrected Speed: -79.32 cm/s
# Measured Distance: 45.07 cm | Current Speed: -48.97 cm/s | Corrected Speed: -71.01 cm/s
# Measured Distance: 40.13 cm | Current Speed: -48.64 cm/s | Corrected Speed: -68.17 cm/s
# Measured Distance: 42.53 cm | Current Speed: 23.35 cm/s | Corrected Speed: 2.41 cm/s
# Measured Distance: 44.69 cm | Current Speed: 21.10 cm/s | Corrected Speed: 0.94 cm/s
# Measured Distance: 47.94 cm | Current Speed: 31.88 cm/s | Corrected Speed: 14.33 cm/s
# Measured Distance: 51.58 cm | Current Speed: 35.46 cm/s | Corrected Speed: 9.33 cm/s
# Measured Distance: 46.12 cm | Current Speed: -53.67 cm/s | Corrected Speed: -68.09 cm/s
# Measured Distance: 45.05 cm | Current Speed: -10.56 cm/s | Corrected Speed: -28.74 cm/s
# Measured Distance: 41.20 cm | Current Speed: -37.85 cm/s | Corrected Speed: -51.34 cm/s
# Measured Distance: 42.18 cm | Current Speed: 9.67 cm/s | Corrected Speed: -6.17 cm/s
# Measured Distance: 38.22 cm | Current Speed: -39.20 cm/s | Corrected Speed: -50.05 cm/s
# Measured Distance: 35.99 cm | Current Speed: -22.12 cm/s | Corrected Speed: -33.53 cm/s
# Measured Distance: 35.61 cm | Current Speed: -3.81 cm/s | Corrected Speed: -16.85 cm/s
# Measured Distance: 39.35 cm | Current Speed: 37.06 cm/s | Corrected Speed: 29.12 cm/s
# Measured Distance: 37.53 cm | Current Speed: -17.98 cm/s | Corrected Speed: -26.89 cm/s
# Measured Distance: 33.69 cm | Current Speed: -38.09 cm/s | Corrected Speed: -43.01 cm/s
# Measured Distance: 36.18 cm | Current Speed: 24.60 cm/s | Corrected Speed: 19.51 cm/s
# Simulation stopped.

# %%
import random
import time

# Simüle edilmiş sensör
class SimulatedSensor:
    def __init__(self, initial_value=50, min_value=0, max_value=100):
        self.value = initial_value  # Başlangıç mesafesi
        self.min_value = min_value  # Minimum mesafe
        self.max_value = max_value  # Maksimum mesafe
        self.prev_value = initial_value  # Önceki mesafe
        self.prev_time = time.time()  # Başlangıç zamanı

    def read(self):
        """Sensör verisini oku ve rastgele bir değişim uygula."""
        noise = random.uniform(-5, 5)  # Gürültü
        self.value += random.uniform(-1, 1) + noise
        self.value = max(self.min_value, min(self.max_value, self.value))  # Sınırlandırma
        return self.value

    def get_speed(self):
        """Hızı, mesafe ve zaman farkına göre hesapla."""
        current_time = time.time()
        delta_time = current_time - self.prev_time  # Zaman farkı
        delta_distance = self.value - self.prev_value  # Mesafe farkı

        if delta_time > 0:
            speed = delta_distance / delta_time
        else:
            speed = 0

        self.prev_value = self.value
        self.prev_time = current_time
        return speed


# PI Kontrolcüsü
class PIController:
    def __init__(self, target_speed, Kp, Ki, Kd=0.05):
        self.target_speed = target_speed  # Hedef hız
        self.Kp = Kp  # Proportional kazancı
        self.Ki = Ki  # Integral kazancı
        self.Kd = Kd  # Mesafe kazancı
        self.integral = 0  # Hata birikimi

    def control(self, current_speed, measured_distance, target_distance=50):
        """Hedef mesafeye ulaşmak için PI kontrol sinyali üret."""
        # Mesafe hatası
        distance_error = target_distance - measured_distance
        
        # Mesafeye göre hız yönlendirmesi
        if distance_error > 0:
            # Hedefe yaklaşmak için hız pozitif olmalı
            speed_error = abs(self.target_speed - current_speed)
        else:
            # Hedefe yaklaşmak için hız negatif olmalı
            speed_error = -abs(self.target_speed - current_speed)

        # Hata birikimi (integral terimi)
        self.integral += speed_error

        # Kontrol sinyali
        control_signal = (
            self.Kp * speed_error +  # Hız hatası katkısı
            self.Ki * self.integral +  # Hata birikimi katkısı
            self.Kd * distance_error   # Mesafe hatası katkısı
        )

        return control_signal


# Simülasyon
sensor = SimulatedSensor(initial_value=70)  # Başlangıç mesafesi 70 cm
pi_controller = PIController(target_speed=0, Kp=0.3, Ki=0.25, Kd=0.08)  # Hedef hız 0 cm/s (durgunluk)

try:
    while True:
        # Sensör verisi al
        measured_distance = sensor.read()
        # Hızı hesapla
        current_speed = sensor.get_speed()

        # PI kontrolünü uygula
        control_signal = pi_controller.control(
            current_speed=current_speed,
            measured_distance=measured_distance,
            target_distance=50  # Hedef mesafe
        )

        # Kontrol sinyali ile hız düzeltilir
        corrected_speed = current_speed + control_signal

        # Durum bilgisi yazdır
        print(
            f"Measured Distance: {measured_distance:.2f} cm | "
            f"Current Speed: {current_speed:.2f} cm/s | "
            f"Corrected Speed: {corrected_speed:.2f} cm/s",
            flush=True
        )

        # Bekleme (100 ms)
        time.sleep(0.1)

except KeyboardInterrupt:
    print("Simulation stopped.")
# Out:
# Measured Distance: 72.32 cm | Current Speed: 0.00 cm/s | Corrected Speed: -1.79 cm/s
# Measured Distance: 68.94 cm | Current Speed: -33.00 cm/s | Corrected Speed: -52.66 cm/s
# Measured Distance: 72.21 cm | Current Speed: 32.16 cm/s | Corrected Speed: 4.44 cm/s
# Measured Distance: 68.02 cm | Current Speed: -40.86 cm/s | Corrected Speed: -81.07 cm/s
# Measured Distance: 66.64 cm | Current Speed: -13.63 cm/s | Corrected Speed: -48.96 cm/s
# Measured Distance: 67.67 cm | Current Speed: 10.10 cm/s | Corrected Speed: -26.78 cm/s
# Measured Distance: 63.53 cm | Current Speed: -40.67 cm/s | Corrected Speed: -96.56 cm/s
# Measured Distance: 58.68 cm | Current Speed: -47.82 cm/s | Corrected Speed: -117.42 cm/s
# Measured Distance: 55.22 cm | Current Speed: -34.19 cm/s | Corrected Speed: -107.96 cm/s
# Measured Distance: 58.71 cm | Current Speed: 34.68 cm/s | Corrected Speed: -48.20 cm/s
# Measured Distance: 59.24 cm | Current Speed: 5.19 cm/s | Corrected Speed: -70.18 cm/s
# Measured Distance: 56.22 cm | Current Speed: -29.53 cm/s | Corrected Speed: -119.35 cm/s
# Measured Distance: 53.73 cm | Current Speed: -24.60 cm/s | Corrected Speed: -118.89 cm/s
# Measured Distance: 49.20 cm | Current Speed: -44.94 cm/s | Corrected Speed: -106.77 cm/s
# Measured Distance: 48.49 cm | Current Speed: -7.01 cm/s | Corrected Speed: -78.41 cm/s
# Measured Distance: 49.54 cm | Current Speed: 10.44 cm/s | Corrected Speed: -57.40 cm/s
# Measured Distance: 47.64 cm | Current Speed: -18.42 cm/s | Corrected Speed: -79.11 cm/s
# Measured Distance: 46.64 cm | Current Speed: -9.89 cm/s | Corrected Speed: -70.59 cm/s
# Measured Distance: 42.96 cm | Current Speed: -36.41 cm/s | Corrected Speed: -79.75 cm/s
# Measured Distance: 44.89 cm | Current Speed: 18.96 cm/s | Corrected Speed: -25.03 cm/s
# Measured Distance: 47.21 cm | Current Speed: 22.87 cm/s | Corrected Speed: -14.43 cm/s
# Measured Distance: 48.82 cm | Current Speed: 15.88 cm/s | Corrected Speed: -19.67 cm/s
# Measured Distance: 50.35 cm | Current Speed: 14.94 cm/s | Corrected Speed: -33.71 cm/s
# Measured Distance: 48.09 cm | Current Speed: -22.03 cm/s | Corrected Speed: -53.90 cm/s
# Measured Distance: 52.73 cm | Current Speed: 45.48 cm/s | Corrected Speed: -18.38 cm/s
# Measured Distance: 54.63 cm | Current Speed: 18.75 cm/s | Corrected Speed: -41.93 cm/s
# Measured Distance: 53.93 cm | Current Speed: -6.94 cm/s | Corrected Speed: -65.77 cm/s
# Measured Distance: 48.26 cm | Current Speed: -55.91 cm/s | Corrected Speed: -81.45 cm/s
# Measured Distance: 50.78 cm | Current Speed: 24.95 cm/s | Corrected Speed: -31.29 cm/s
# Measured Distance: 50.24 cm | Current Speed: -5.27 cm/s | Corrected Speed: -56.87 cm/s
# Measured Distance: 46.20 cm | Current Speed: -39.71 cm/s | Corrected Speed: -67.57 cm/s
# Measured Distance: 49.48 cm | Current Speed: 32.34 cm/s | Corrected Speed: 10.10 cm/s
# Measured Distance: 45.91 cm | Current Speed: -35.32 cm/s | Corrected Speed: -47.56 cm/s
# Measured Distance: 46.28 cm | Current Speed: 3.63 cm/s | Corrected Speed: -17.24 cm/s
# Measured Distance: 44.31 cm | Current Speed: -19.53 cm/s | Corrected Speed: -30.59 cm/s
# Measured Distance: 45.53 cm | Current Speed: 12.12 cm/s | Corrected Speed: 1.77 cm/s
# Measured Distance: 44.86 cm | Current Speed: -6.65 cm/s | Corrected Speed: -16.92 cm/s
# Measured Distance: 47.41 cm | Current Speed: 24.97 cm/s | Corrected Speed: 26.24 cm/s
# Measured Distance: 49.51 cm | Current Speed: 20.82 cm/s | Corrected Speed: 25.87 cm/s
# Measured Distance: 54.30 cm | Current Speed: 47.53 cm/s | Corrected Speed: 19.82 cm/s
# Measured Distance: 49.98 cm | Current Speed: -42.43 cm/s | Corrected Speed: -32.20 cm/s
# Measured Distance: 53.93 cm | Current Speed: 38.93 cm/s | Corrected Speed: 14.70 cm/s
# Measured Distance: 56.74 cm | Current Speed: 27.57 cm/s | Corrected Speed: -0.37 cm/s
# Measured Distance: 55.74 cm | Current Speed: -9.80 cm/s | Corrected Speed: -34.78 cm/s
# Measured Distance: 57.45 cm | Current Speed: 16.78 cm/s | Corrected Speed: -14.62 cm/s
# Measured Distance: 60.18 cm | Current Speed: 26.56 cm/s | Corrected Speed: -14.64 cm/s
# Measured Distance: 65.18 cm | Current Speed: 49.28 cm/s | Corrected Speed: -11.45 cm/s
# Measured Distance: 62.73 cm | Current Speed: -24.25 cm/s | Corrected Speed: -83.33 cm/s
# Measured Distance: 64.99 cm | Current Speed: 22.05 cm/s | Corrected Speed: -42.07 cm/s
# Measured Distance: 61.50 cm | Current Speed: -34.23 cm/s | Corrected Speed: -110.29 cm/s
# Measured Distance: 64.48 cm | Current Speed: 29.30 cm/s | Corrected Speed: -52.84 cm/s
# Measured Distance: 62.76 cm | Current Speed: -16.75 cm/s | Corrected Speed: -99.18 cm/s
# Measured Distance: 59.54 cm | Current Speed: -31.77 cm/s | Corrected Speed: -126.39 cm/s
# Measured Distance: 62.05 cm | Current Speed: 24.73 cm/s | Corrected Speed: -74.16 cm/s
# Measured Distance: 56.34 cm | Current Speed: -55.92 cm/s | Corrected Speed: -177.69 cm/s
# Measured Distance: 59.84 cm | Current Speed: 34.60 cm/s | Corrected Speed: -89.70 cm/s
# Measured Distance: 59.63 cm | Current Speed: -2.06 cm/s | Corrected Speed: -117.11 cm/s
# Measured Distance: 57.58 cm | Current Speed: -20.17 cm/s | Corrected Speed: -145.53 cm/s
# Measured Distance: 52.21 cm | Current Speed: -52.94 cm/s | Corrected Speed: -200.93 cm/s
# Measured Distance: 54.30 cm | Current Speed: 20.35 cm/s | Corrected Speed: -123.12 cm/s
# Measured Distance: 54.84 cm | Current Speed: 5.28 cm/s | Corrected Speed: -135.03 cm/s
# Measured Distance: 51.60 cm | Current Speed: -31.64 cm/s | Corrected Speed: -187.52 cm/s
# Measured Distance: 52.68 cm | Current Speed: 10.48 cm/s | Corrected Speed: -141.75 cm/s
# Measured Distance: 56.64 cm | Current Speed: 38.93 cm/s | Corrected Speed: -131.88 cm/s
# Measured Distance: 55.72 cm | Current Speed: -8.99 cm/s | Corrected Speed: -173.00 cm/s
# Measured Distance: 54.97 cm | Current Speed: -7.37 cm/s | Corrected Speed: -172.67 cm/s
# Measured Distance: 52.16 cm | Current Speed: -27.51 cm/s | Corrected Speed: -205.50 cm/s
# Measured Distance: 52.93 cm | Current Speed: 7.53 cm/s | Corrected Speed: -166.42 cm/s
# Measured Distance: 50.36 cm | Current Speed: -25.28 cm/s | Corrected Speed: -210.67 cm/s
# Measured Distance: 51.64 cm | Current Speed: 12.62 cm/s | Corrected Speed: -172.23 cm/s
# Measured Distance: 52.60 cm | Current Speed: 9.42 cm/s | Corrected Speed: -176.90 cm/s
# Measured Distance: 55.64 cm | Current Speed: 29.79 cm/s | Corrected Speed: -170.33 cm/s
# Measured Distance: 60.52 cm | Current Speed: 47.86 cm/s | Corrected Speed: -170.03 cm/s
# Measured Distance: 61.61 cm | Current Speed: 10.77 cm/s | Corrected Speed: -198.78 cm/s
# Measured Distance: 58.36 cm | Current Speed: -31.60 cm/s | Corrected Speed: -255.04 cm/s
# Measured Distance: 58.29 cm | Current Speed: -0.71 cm/s | Corrected Speed: -215.05 cm/s
# Measured Distance: 58.97 cm | Current Speed: 6.73 cm/s | Corrected Speed: -211.16 cm/s
# Measured Distance: 57.26 cm | Current Speed: -16.90 cm/s | Corrected Speed: -241.93 cm/s
# Measured Distance: 56.70 cm | Current Speed: -5.46 cm/s | Corrected Speed: -228.37 cm/s
# Measured Distance: 54.66 cm | Current Speed: -19.97 cm/s | Corrected Speed: -252.06 cm/s
# Measured Distance: 49.90 cm | Current Speed: -46.65 cm/s | Corrected Speed: -246.71 cm/s
# Measured Distance: 51.16 cm | Current Speed: 12.32 cm/s | Corrected Speed: -208.62 cm/s
# Measured Distance: 50.95 cm | Current Speed: -2.09 cm/s | Corrected Speed: -220.47 cm/s
# Measured Distance: 55.25 cm | Current Speed: 42.38 cm/s | Corrected Speed: -199.02 cm/s
# Measured Distance: 58.33 cm | Current Speed: 30.38 cm/s | Corrected Speed: -215.26 cm/s
# Measured Distance: 55.94 cm | Current Speed: -23.31 cm/s | Corrected Speed: -272.47 cm/s
# Measured Distance: 51.99 cm | Current Speed: -38.97 cm/s | Corrected Speed: -302.25 cm/s
# Measured Distance: 49.02 cm | Current Speed: -29.28 cm/s | Corrected Speed: -264.53 cm/s
# Measured Distance: 51.94 cm | Current Speed: 28.74 cm/s | Corrected Speed: -231.34 cm/s
# Measured Distance: 52.12 cm | Current Speed: 1.79 cm/s | Corrected Speed: -250.66 cm/s
# Measured Distance: 49.50 cm | Current Speed: -25.87 cm/s | Corrected Speed: -263.35 cm/s
# Measured Distance: 49.41 cm | Current Speed: -0.94 cm/s | Corrected Speed: -245.65 cm/s
# Measured Distance: 47.53 cm | Current Speed: -18.59 cm/s | Corrected Speed: -253.21 cm/s
# Measured Distance: 53.31 cm | Current Speed: 57.11 cm/s | Corrected Speed: -214.96 cm/s
# Measured Distance: 56.07 cm | Current Speed: 27.27 cm/s | Corrected Speed: -242.89 cm/s
# Measured Distance: 58.32 cm | Current Speed: 22.27 cm/s | Corrected Speed: -252.13 cm/s
# Measured Distance: 61.52 cm | Current Speed: 31.63 cm/s | Corrected Speed: -253.75 cm/s
# Measured Distance: 64.21 cm | Current Speed: 26.59 cm/s | Corrected Speed: -264.14 cm/s
# Measured Distance: 63.78 cm | Current Speed: -4.31 cm/s | Corrected Speed: -289.39 cm/s
# Measured Distance: 61.06 cm | Current Speed: -26.99 cm/s | Corrected Speed: -325.40 cm/s
# Measured Distance: 63.92 cm | Current Speed: 28.32 cm/s | Corrected Speed: -277.81 cm/s
# Measured Distance: 63.63 cm | Current Speed: -2.89 cm/s | Corrected Speed: -302.08 cm/s
# Measured Distance: 58.70 cm | Current Speed: -48.70 cm/s | Corrected Speed: -373.42 cm/s
# Measured Distance: 60.83 cm | Current Speed: 21.02 cm/s | Corrected Speed: -300.82 cm/s
# Measured Distance: 59.23 cm | Current Speed: -15.74 cm/s | Corrected Speed: -339.80 cm/s
# Measured Distance: 58.42 cm | Current Speed: -8.02 cm/s | Corrected Speed: -331.71 cm/s
# Measured Distance: 57.35 cm | Current Speed: -10.62 cm/s | Corrected Speed: -337.66 cm/s
# Measured Distance: 54.59 cm | Current Speed: -27.37 cm/s | Corrected Speed: -366.05 cm/s
# Measured Distance: 58.21 cm | Current Speed: 35.30 cm/s | Corrected Speed: -314.87 cm/s
# Measured Distance: 56.04 cm | Current Speed: -21.42 cm/s | Corrected Speed: -372.61 cm/s
# Measured Distance: 52.39 cm | Current Speed: -36.06 cm/s | Corrected Speed: -400.37 cm/s
# Measured Distance: 53.47 cm | Current Speed: 10.57 cm/s | Corrected Speed: -348.82 cm/s
# Measured Distance: 55.42 cm | Current Speed: 19.25 cm/s | Corrected Speed: -347.71 cm/s
# Measured Distance: 54.91 cm | Current Speed: -5.00 cm/s | Corrected Speed: -368.90 cm/s
# Measured Distance: 51.98 cm | Current Speed: -28.80 cm/s | Corrected Speed: -406.81 cm/s
# Measured Distance: 55.61 cm | Current Speed: 35.77 cm/s | Corrected Speed: -353.56 cm/s
# Measured Distance: 55.35 cm | Current Speed: -2.52 cm/s | Corrected Speed: -382.48 cm/s
# Measured Distance: 58.32 cm | Current Speed: 29.30 cm/s | Corrected Speed: -366.26 cm/s
# Measured Distance: 55.17 cm | Current Speed: -31.27 cm/s | Corrected Speed: -434.99 cm/s
# Measured Distance: 51.52 cm | Current Speed: -35.98 cm/s | Corrected Speed: -449.82 cm/s
# Measured Distance: 52.53 cm | Current Speed: 10.00 cm/s | Corrected Speed: -398.62 cm/s
# Measured Distance: 53.77 cm | Current Speed: 12.35 cm/s | Corrected Speed: -400.16 cm/s
# Measured Distance: 49.11 cm | Current Speed: -45.89 cm/s | Corrected Speed: -429.09 cm/s
# Measured Distance: 49.01 cm | Current Speed: -0.98 cm/s | Corrected Speed: -397.39 cm/s
# Measured Distance: 44.03 cm | Current Speed: -48.82 cm/s | Corrected Speed: -418.28 cm/s
# Measured Distance: 39.83 cm | Current Speed: -41.44 cm/s | Corrected Speed: -402.42 cm/s
# Simulation stopped.
